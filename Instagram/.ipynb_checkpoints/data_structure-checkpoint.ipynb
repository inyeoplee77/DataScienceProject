# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

music_db = file('Music_DB.txt','r')
movie_db = file('Movie_DB.txt','r')
for a in music_db:
    if (a.split(':')[1].strip()=='None'):
        continue
    if(a.split(':')[0]=='artist'):
        _data[a.split(':')[1].strip()]=0
    elif(a.split(':')[0]=='tempo'):
        tempo = float(a.split(':')[1].strip())
        if(tempo > max_tempo):
            max_tempo = tempo
        elif(tempo < min_tempo):
            min_tempo = tempo
    elif(a.split(':')[0]=='instrumentalness'):
        inst = float(a.split(':')[1].strip())
        if(inst > max_instru):
            max_instru = inst
        elif(inst < min_instru):
            min_instru = inst
    elif(a.split(':')[0]=='loudness'):
        loud = float(a.split(':')[1].strip())
        if(loud > max_loudness):
            max_loudness = loud
        elif(loud < min_loudness):
            min_loudness = loud
    elif(a.split(':')[0]=='song_type'):
        song_type = a.split(':')[1].split(',')
        for b in song_type:
            _data[b.strip()]=0
    elif(a.split(':')[0]=='artist_terms'):
        art_term = a.split(':')[1].split(',')
        for b in art_term:
            _data[b.strip()]=0

for a in movie_db:
    if(a.split(':')[0]=='director'):
        director = a.split(':')[1].split(',')
        for b in director:
            _data[b]=0
    elif(a.split(':')[0]=='stars'):
        stars = a.split(':')[1].split(',')
        for b in stars:
            _data[b]=0
    elif(a.split(':')[0]=='genres'):
        genres = a.split(':')[1].split(',')
        for b in genres:
            _data[b]=0
     #   _data[a.split(':')[1].strip()]=0
    #elif(a.split(':')[0]=='votes'):
for a in range(0,9):
    string = 'energy:'+(str)(0.1*a)+'~'+(str)(0.1*(a+1))
    _data[string]=0
    string = 'liveness:'+(str)(0.1*a)+'~'+(str)(0.1*(a+1))
    _data[string]=0
    string = 'tempo:'+(str)(15*a)+'~'+(str)(15*(a+1))
    _data[string]=0
    string = 'speechiness:'+(str)(0.1*a)+'~'+(str)(0.1*(a+1))
    _data[string]=0
    string = 'acousticness:'+(str)(0.1*a)+'~'+(str)(0.1*(a+1))
    _data[string]=0
    string = 'danceability:'+(str)(0.1*a)+'~'+(str)(0.1*(a+1))
    _data[string]=0
    string = 'instrumantalness:'+(str)(3*a)+'~'+(str)(3*(a+1))
    _data[string]=0
    string = 'valence:'+(str)(0.1*a)+'~'+(str)(0.1*(a+1))
    _data[string]=0
    string = 'hotttnesss:'+(str)(0.03*a)+'~'+(str)(0.03*(a+1))
    _data[string]=0
    string = 'vote:'+(str)(150000*a)+'~'+(str)(150000*(a+1))
    _data[string]=0
    string = 'rate:'+(str)(1*a)+'~'+(str)(1*(a+1))
    _data[string]=0
    string = 'year:'+(str)(1915+10*a)+'~'+(str)(1914+10*(a+1))
    _data[string]=0
    
print new_data.keys()
